# %%
# !ls
# Out:
# Delhi_2020.xls Untitled.ipynb

# %%
import pandas as pd

# %%
pd.read_excel?

# %%
df = pd.read_excel("Delhi_2020.xls", sheet_name = None)
# Out:
# _locate_stream(Workbook): seen
#     0  5 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#    20  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#   440= 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#   460  4 4 4 4 4 4 4 4 4 4 3 2 2 2 2
# ---------------------------------------------------------------------------
# CompDocError                              Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 df = pd.read_excel("Delhi_2020.xls", sheet_name = None)
#
# File /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
df = pd.read_excel("Delhi_2020.xlsx", sheet_name = None, header=[1])

# %%
v.iterrows?

# %%
', '.join(['1', '2', '3'])
# Out:
# '1, 2, 3'

# %%
for k,v in df.items():
    const_num = int(k.split("-")[1])
    const_name = v.columns[3]
    print(const_num, const_name)
    display(v)
    for idx, row in v.iterrows():
        tmp_row = row.dropna()
        str_row = [str(i) for i in tmp_row]
        print(', '.join(str_row))
#         print(', '.join([str(i) for i in row.dropna()]))
    break
# Out:
# 1 NARELA-GEN
#                                      State/UT & Code   \
# 0                                         CANDIDATES
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                           ELECTORS
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                            VOTERS
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
df_2003 = pd.read_csv("tabula-2003_constituency_summary.csv", header = None)

# %%
for idx, row in df_2003.iterrows():
    tmp_row = row.dropna()
    str_row = [str(i) for i in tmp_row]
    print(', '.join(str_row))
    if(idx > 10):
        break
# Out:
# FCieOldN7:STITUENCY  :  1 - SAROJINI NAGAR
# MALE, FEMALE, TOTAL
# I.  CANDIDATES
# 1. NOMINATED 6, 0, 6
# 2. REJECTED 1, 0, 1
# 3. WITHDRAWN 0, 0, 0
# 4. CONTESTED 5, 0, 5
# 5. FORFEITED DEPOSIT 3, 0, 3
# II.  ELECTORS
# 1. GENERAL 51181, 41601, 92782
# 2. SERVICE 30, 21, 51
# 3. TOTAL 51211, 41622, 92833
